# %% [markdown]
# <a href="https://colab.research.google.com/github/ananya04-s/Machinelearning/blob/main/Customer_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer_Segmentation
#
# This notebook is designed for **Google Colab**.

# %%
url='https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv'

# %%
# !pip -q install scikit-learn pandas matplotlib

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
df=pd.read_csv(url)
X=df.iloc[:,:4]
km=KMeans(n_clusters=3,random_state=42,n_init=10)
lab=km.fit_predict(X)
plt.scatter(X.iloc[:,0],X.iloc[:,1],c=lab)
plt.xlabel(X.columns[0]); plt.ylabel(X.columns[1]); plt.show()
